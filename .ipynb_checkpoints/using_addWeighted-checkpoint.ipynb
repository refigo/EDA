# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !ls ./data
# Out:
# dog_and_pinkwink.jpg  puppy1.jpg  puppy2.jpg  watermark_no_copy.png

# %%
img1 = cv2.imread('./data/dog_and_pinkwink.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1);

# %%
img2 = cv2.imread('./data/watermark_no_copy.png')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2);

# %%
img1.shape, img2.shape
# Out:
# ((1440, 1080, 3), (1280, 1277, 3))

# %%
cv2.addWeighted(src1=img1, alpha=0.5, src2=img2, beta=0.5, gamma=0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 cv2.addWeighted(src1=img1, alpha=0.5, src2=img2, beta=0.5, gamma=0)
#
# error: OpenCV(4.7.0) /io/opencv/modules/core/src/arithm.cpp:647: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img1.shape, img2.shape
# Out:
# ((1440, 1080, 3), (1440, 1080, 3))

# %%
blended = cv2.addWeighted(src1=img1, alpha=0.5, src2=img2, beta=0.5, gamma=0)
plt.imshow(blended);

# %%
img2 = cv2.resize(img2, (600, 600))
plt.imshow(img2);

# %%
large_img = img1.copy()
small_img = img2.copy()

x_offset = 100
y_offset = 50

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

x_end, y_end
# Out:
# (700, 650)

# %%
large_img[y_offset:y_end, x_offset:x_end] = small_img
plt.imshow(large_img);
