# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# !ls ./data
# Out:
# puppy1.jpg  puppy2.jpg

# %%
pic = Image.open('./data/puppy2.jpg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
pic2 = Image.open('./data/puppy1.jpg')
pic2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr
# Out:
# array([[[ 58, 126, 173],
#         [ 58, 126, 173],
#         [ 58, 126, 173],
#         ...,
#         [190, 161, 119],
#         [189, 161, 122],
#         [187, 159, 120]],
#
#        [[ 58, 126, 173],
#         [ 58, 126, 173],
#         [ 58, 126, 173],
#         ...,
#         [190, 158, 119],
#         [190, 158, 119],
#         [189, 157, 118]],
#
#        [[ 58, 126, 173],
#         [ 58, 126, 173],
#         [ 59, 127, 174],
#         ...,
#         [191, 155, 119],
#         [194, 156, 119],
#         [194, 156, 117]],
#
#        ...,
#
#        [[219, 215, 204],
#         [221, 217, 206],
#         [215, 211, 200],
#         ...,
#         [215, 209, 197],
#         [215, 209, 197],
#         [215, 209, 197]],
#
#        [[215, 211, 200],
#         [212, 208, 197],
#         [204, 200, 189],
#         ...,
#         [215, 209, 197],
#         [215, 209, 197],
#         [215, 209, 197]],
#
#        [[216, 212, 201],
#         [205, 201, 190],
#         [194, 190, 179],
#         ...,
#         [214, 208, 196],
#         [214, 208, 196],
#         [215, 209, 197]]], dtype=uint8)

# %%
pic_arr.shape
# Out:
# (427, 640, 3)

# %%
pic_green = pic_arr.copy()
plt.imshow(pic_green);

# %%
plt.imshow(pic_green[:,:,1]);

# %%
pic_green[:,:,1]
# Out:
# array([[126, 126, 126, ..., 161, 161, 159],
#        [126, 126, 126, ..., 158, 158, 157],
#        [126, 126, 127, ..., 155, 156, 156],
#        ...,
#        [215, 217, 211, ..., 209, 209, 209],
#        [211, 208, 200, ..., 209, 209, 209],
#        [212, 201, 190, ..., 208, 208, 209]], dtype=uint8)

# %%
plt.imshow(pic_green[:,:,1], cmap='gray');

# %%
pic_green[:,:,0] = 0
plt.imshow(pic_green);

# %%
pic_green[:,:,2] = 0
plt.imshow(pic_green);
