# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./data/puppy2.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
tmp = cv2.imread('./data/notexisted.jpg')
type(tmp)
# Out:
# [ WARN:0@85.563] global loadsave.cpp:244 findDecoder imread_('./data/notexisted.jpg'): can't open/read file: check file path/integrity
# NoneType

# %%
img.shape
# Out:
# (427, 640, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img);

# %%
img_gray = cv2.imread('./data/puppy2.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray');

# %%
new_img = cv2.resize(fix_img, (400, 250))
plt.imshow(new_img);

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %%
plt.imshow(cv2.flip(fix_img, -1))
